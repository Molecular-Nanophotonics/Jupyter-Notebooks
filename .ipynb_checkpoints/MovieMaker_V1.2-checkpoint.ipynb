# %% [markdown]
# # Movie Maker for TDMS files using FFmpeg

# %% [markdown]
# ### Required packages:

# %% [markdown]
# - npTDMS (!pip install nptdms)
# - FFmpeg (http://www.wikihow.com/Install-FFmpeg-on-Windows)

# %%
import numpy as np
import matplotlib
#matplotlib.use("agg")
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.animation as animation # https://matplotlib.org/api/animation_api.html

import fnmatch
import sys, os

from IPython.display import clear_output

from nptdms import TdmsFile # this library contains the actual TDMS loading parts
#from ipywidgets import interact

from matplotlib import colors
import pickle
from scipy import ndimage

import pandas as pd
import trackpy as tp

# %%
fdir = 'E:/' # set the "Select Files..." dialog start directory to the notebook directory
def openFilesDialog(fdir):
    from PyQt5.QtWidgets import QApplication,QFileDialog
    app = QApplication([dir])
    files = QFileDialog.getOpenFileNames(None, "Select Files...", fdir, filter='TDMS Files (*.tdms);;All Files (*)')
    return files[0]

def loadTDMSImages(file):
    global exposure, dimx, dimy, binning
    tdms_file = TdmsFile(file)
    p=tdms_file.object().properties   
    dimx=int(p['dimx'])  
    dimy=int(p['dimy'])
    frames=int(p['dimz'])
    binning=int(p['binning'])
    exposure=float(p['exposure'])
    images=tdms_file.channel_data('Image','Image')
    return images.reshape(frames,dimx,dimy)

# %% [markdown]
# ## Select files to process

# %%
files = openFilesDialog(fdir)
fdir = os.path.dirname(files[0]) # set the dialog start directory to the selected directory
print('Selected Files:')
for file in files:
    print(file)
# Out:
# Selected Files:
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_001_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_002_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_003_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_004_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_005_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_006_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_007_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_008_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_009_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_010_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_011_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_012_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_013_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_014_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_015_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_016_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_017_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_018_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_019_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_020_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_021_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_022_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_023_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_024_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_025_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_026_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_027_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_028_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_029_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_030_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_031_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_032_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_033_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_034_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_035_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_036_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_037_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_038_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_039_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_040_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_041_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_042_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_043_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_044_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_045_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_046_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_047_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_048_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_049_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_050_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_051_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_052_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_053_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_054_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_055_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_056_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_057_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_058_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_059_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_060_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_061_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_062_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_063_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_064_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_065_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_066_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_067_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_068_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_069_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_070_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_071_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_072_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_073_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_074_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_075_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_076_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_077_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_078_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_079_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_080_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_081_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_082_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_083_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_084_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_085_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_086_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_087_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_088_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_089_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_090_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_091_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_092_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_093_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_094_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_095_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_096_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_097_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_098_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_099_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_100_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_101_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_102_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_103_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_104_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_105_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_106_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_107_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_108_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_109_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_110_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_111_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_112_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_113_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_114_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_115_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_116_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_117_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_118_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_119_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_120_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_121_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_122_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_123_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_124_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_125_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_126_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_127_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_128_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_129_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_130_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_131_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_132_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_133_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_134_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_135_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_136_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_137_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_138_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_139_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_140_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_141_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_142_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_143_movie.tdms
# E:/180529_A-Beta_Fibril_ThT_High_Trapping+Monomer/Set1_144_movie.tdms

# %%
# Trajectory
#f = pd.read_pickle('E:/180227_A-Beta_Fibril_ThT_Trapping/Set4_006_features.pkl')
#t = tp.link_df(f, search_range=25, memory=3)
#df = tp.filter_stubs(t, 10)

# %% [markdown]
# ##  Select color map

# %%
try:  
    cmap = pickle.load(open('colormaps/cmap_tht.pkl', 'rb'))
    #cmap = 'gray'
    #cmap = 'viridis'
except Exception as e:
    cmap = 'gray' # default
    print(e, 'Using the default color map.')

# %% [markdown]
# ## Here, you can test color scale, overlay, ...

# %%
# find the first *_movie.tdms in the list of files and load it 
i = [i for i, file in enumerate(files) if fnmatch.fnmatch(file, '*_movie.tdms')][0]
i = 49
images = loadTDMSImages(files[i])

# %%
k = 554
image = images[k]

# color scale 
autoscale = False
vmin = 200
vmax = 800

subx = dimx  
suby = dimy

# overlay
scalebar = True
if scalebar:
    um2px = 0.0577*binning # µm/px
    sb_um = 3 # µm 
    sb_x = 0.825*(dimx+subx)/2
    sb_y = 0.825*(dimy+suby)/2
    sb_px = int(np.round(sb_um/um2px))

# filters
medianfilter = False
median = 2
if medianfilter:
    image = ndimage.median_filter(image, median) 

# mask
mask = True
if mask:
    x0 = 60; y0 = 61
    radius = 38
    xx, yy= np.meshgrid(np.arange(0, dimx, 1), np.arange(0, dimy, 1))
    maskimage = (((xx - x0)**2 + (yy - y0)**2) < (radius)**2).astype(int)
    image = image*maskimage

fig = plt.figure(figsize=(5,5), dpi=100)
ax = fig.add_subplot(1,1,1)

if autoscale:
    ax.imshow(image, cmap=cmap)
else:
    ax.imshow(image, cmap=cmap, vmin=vmin, vmax=vmax)
if scalebar:
    ax.text(sb_x, sb_y, str(sb_um) + ' µm', va='center',ha='center',color='w',fontsize=20)

#ax.set_xlim(x0-subx/2, x0+subx/2)
#ax.set_ylim(y0+suby/2, y0-suby/2)

if subx != dimx or suby != dimy:
    ax.set_xlim((dimx-subx)/2, (dimx+subx)/2)
    ax.set_ylim((dimy+suby)/2, (dimy-suby)/2)

#ax.text(425, 50, 'On', va='center',ha='left',color='w',fontsize=20)
ri = 38
ax.add_patch(plt.Circle((x0, y0), radius=ri, color='w', ls='--', lw=2, fill=False))
#ro = 50
#ax.add_patch(plt.Circle((x0, y0), radius=ro, color='w', ls='-', lw=2, fill=False))

ax.plot([sb_x-sb_px/2, sb_x+sb_px/2], [1.075*sb_y, 1.075*sb_y], 'w', lw=5);

fig.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=None, hspace=None)
plt.axis('off')

# trajectory
#ax.plot(f['x'].tolist()[0:k], f['y'].tolist()[0:k], 'w', alpha=0.25)

# save a preview image
export = True
if export:
    plt.savefig(files[i].replace('_movie.tdms','.png'), dpi=300)

# %% [markdown]
# ## Process files individually

# %%
ffmpegWriter = animation.writers['ffmpeg']

fig = plt.figure(figsize=(5,5), dpi=100)
ax = fig.add_subplot(1,1,1)
fig.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=None, hspace=None)
#im = plt.imshow(images[0], cmap=cmap) # vmax=...
# scale bar
#plt.text(sb_x, sb_y, str(sb_um) + ' µm', va='center',ha='center',color='w',fontsize=20)
#plt.plot([sb_x-sb_px/2, sb_x+sb_px/2], [1.075*sb_y, 1.075*sb_y], 'w', lw=5)
plt.axis('off')
        
#images = np.zeros(0)        
for file in files:
    if fnmatch.fnmatch(file,'*_movie.tdms'): # load only the *_movie.tdms files of the selected files
        images = loadTDMSImages(file)
        if autoscale:
            im = plt.imshow(images[0], cmap=cmap)
        else:
            im = plt.imshow(images[0], cmap=cmap, vmin=vmin, vmax=vmax)
        # overlay
        if scalebar:
            ax.text(sb_x, sb_y, str(sb_um) + ' µm', va='center', ha='center', color='w', fontsize=20)
            ax.plot([sb_x-sb_px/2, sb_x+sb_px/2], [1.075*sb_y, 1.075*sb_y], 'w', lw=5)

        #ax.add_patch(plt.Circle((x0, y0), radius=r1, color='w', linewidth=1, fill=False))
        if images.shape[0] > 1: # check if there is more than one frame
            writer = ffmpegWriter(fps=1./exposure) # '.mp4'
            with writer.saving(fig, file.replace('_movie.tdms','') + ".mp4", dpi=100): # !!!
                for i in range(images.shape[0]):
                    image = images[i]
                    if medianfilter:
                        image = ndimage.median_filter(image, median)
                    if mask:
                        image = image*maskimage
                    im.set_data(image)
                    writer.grab_frame()
                    if (i % 10 == 0):
                        clear_output(wait=True)
                        print(file + '\n' + 'Progress:', int(i/images.shape[0]*100), '%')
        #else:   
            # save as '.png'
# Out:
# E:/180524_A-Beta_Fibril_ThT_High_Concentration/Set13_001_movie.tdms
# Progress: 44 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-100-75e6e6bf2b49> in <module>()
#      34                         image = image*maskimage
#      35                     im.set_data(image)
# ---> 36                     writer.grab_frame()
#      37                     if (i % 10 == 0):
#      38                         clear_output(wait=True)
#
# C:\Anaconda3\lib\site-packages\matplotlib\animation.py in grab_frame(self, **savefig_kwargs)
#     386             # frame format and dpi.
#     387             self.fig.savefig(self._frame_sink(), format=self.frame_format,
# --> 388                              dpi=self.dpi, **savefig_kwargs)
#     389         except (RuntimeError, IOError) as e:
#     390             out, err = self._proc.communicate()
#
# C:\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    1812             self.set_frameon(frameon)
#    1813
# -> 1814         self.canvas.print_figure(fname, **kwargs)
#    1815
#    1816         if frameon:
#
# C:\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2257                 orientation=orientation,
#    2258                 bbox_inches_restore=_bbox_inches_restore,
# -> 2259                 **kwargs)
#    2260         finally:
#    2261             if bbox_inches and restore_bbox:
#
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_raw(self, filename_or_obj, *args, **kwargs)
#     486
#     487     def print_raw(self, filename_or_obj, *args, **kwargs):
# --> 488         FigureCanvasAgg.draw(self)
#     489         renderer = self.get_renderer()
#     490         original_dpi = renderer.dpi
#
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     428             if toolbar:
#     429                 toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             if toolbar:
#
# C:\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# C:\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1293
#    1294             mimage._draw_list_compositing_images(
# -> 1295                 renderer, self, artists, self.suppressComposite)
#    1296
#    1297             renderer.close_group('figure')
#
# C:\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# C:\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2397             renderer.stop_rasterizing()
#    2398
# -> 2399         mimage._draw_list_compositing_images(renderer, self, artists)
#    2400
#    2401         renderer.close_group('axes')
#
# C:\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# C:\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# C:\Anaconda3\lib\site-packages\matplotlib\image.py in draw(self, renderer, *args, **kwargs)
#     546         else:
#     547             im, l, b, trans = self.make_image(
# --> 548                 renderer, renderer.get_image_magnification())
#     549             if im is not None:
#     550                 renderer.draw_image(gc, l, b, im)
#
# C:\Anaconda3\lib\site-packages\matplotlib\image.py in make_image(self, renderer, magnification, unsampled)
#     772         return self._make_image(
#     773             self._A, bbox, transformed_bbox, self.axes.bbox, magnification,
# --> 774             unsampled=unsampled)
#     775
#     776     def _check_unsampled_image(self, renderer):
#
# C:\Anaconda3\lib\site-packages\matplotlib\image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     464             # (of int or float)
#     465             # or an RGBA array of re-sampled input
# --> 466             output = self.to_rgba(output, bytes=True, norm=False)
#     467             # output is now a correctly sized RGBA array of uint8
#     468
#
# C:\Anaconda3\lib\site-packages\matplotlib\cm.py in to_rgba(self, x, alpha, bytes, norm)
#     274         if norm:
#     275             x = self.norm(x)
# --> 276         rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     277         return rgba
#     278
#
# C:\Anaconda3\lib\site-packages\matplotlib\colors.py in __call__(self, X, alpha, bytes)
#     519
#     520         rgba = np.empty(shape=xa.shape + (4,), dtype=lut.dtype)
# --> 521         lut.take(xa, axis=0, mode='clip', out=rgba)
#     522         if vtype == 'scalar':
#     523             rgba = tuple(rgba[0, :])
#
# KeyboardInterrupt:

# %% [markdown]
# ## Concatenate files

# %%
images = np.array([])
for file in files:
    if fnmatch.fnmatch(file, '*_movie.tdms'): # load only the *_movie.tdms files of the selected files
        if images.size == 0:
            images = loadTDMSImages(file)
        else:
            images = np.concatenate((images, loadTDMSImages(file)), axis=0)
print(images.shape)
# Out:
# (12500, 126, 126)

# %%
ffmpegWriter = animation.writers['ffmpeg']
#writer = ffmpegWriter(fps=1./exposure,codec="msvideo1") # + ".avi" for PowerPoint 2010
writer = ffmpegWriter(fps=1./exposure) # + ".mp4"

fig = plt.figure(figsize=(5,5), dpi=100)
ax = fig.add_subplot(1,1,1)
fig.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=None, hspace=None)
if autoscale:
    im = plt.imshow(images[0], cmap=cmap)
else:
    im = plt.imshow(images[0], cmap=cmap, vmin=vmin, vmax=vmax)
# overlay
if scalebar:
    ax.text(sb_x, sb_y, str(sb_um) + ' µm', va='center', ha='center', color='w', fontsize=20)
    ax.plot([sb_x-sb_px/2, sb_x+sb_px/2], [1.075*sb_y, 1.075*sb_y], 'w', lw=5)
ax.add_patch(plt.Circle((x0, y0), radius=ri, color='w', ls='--', lw=2, fill=False))

if subx != dimx or suby != dimy:
    ax.set_xlim((dimx-subx)/2, (dimx+subx)/2)
    ax.set_ylim((dimy+suby)/2, (dimy-suby)/2)
            
# trajectory
#l, = plt.plot([], [], 'w-', lw=1)
plt.axis('off')

with writer.saving(fig, files[0].replace('_001_movie.tdms','') + ".mp4", dpi=100):
    for i in range(images.shape[0]):
        image = images[i]
        if medianfilter:
            image = ndimage.median_filter(image, median)
        if mask:
            image = image*maskimage
        im.set_data(image)
        # Text
        #if (i == 100):
        #    txt.set_text('On');
        # Trajectory
        #spots=pd.read_pickle(files[0].replace('_001_movie.tdms','') + '_spots.pkl')
        #l.set_data(spots[:i].x, spots[:i].y)
        writer.grab_frame()
        if (i % 10 == 0):
            clear_output(wait=True)
            print('Progress:', int(i/images.shape[0]*100), '%')
# Out:
# Progress: 99 %
